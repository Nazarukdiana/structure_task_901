# %% [markdown]
# <a href="https://colab.research.google.com/github/Nazarukdiana/structure_task_901/blob/main/my_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Структура містить поля: П.І.П., дата народження, адреса, курс і група.Вивести на екран прізвища студентів 2-го курсу.**

# %%
#3 через словник (dict)

students = [
    {"ПІП": "Адамлюк Владислав Романович", "дата народження": "2005-06-16", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Бичко Дар'я Юріївна", "дата народження": "2007-06-20", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Бугрова Юлія Вікторівна", "дата народження": "2007-06-15", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Бурейко Володимир Омелянович", "дата народження": "1960-02-04", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Гончарук Ангеліна Сергіївна", "дата народження": "2007-05-18", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Гріщенко Світлана Василівна", "дата народження": "2007-10-12", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Гунько Іван Романович", "дата народження": "2007-12-21", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Дорош Руслан Миколайович", "дата народження": "2007-02-01", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Журавель Альона Олександрівна", "дата народження": "2007-02-08", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Зінченко Максим Олександрович", "дата народження": "2007-06-30", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Калінін Євген Олексійович", "дата народження": "2001-08-21", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Кисіль Яна Юріївна", "дата народження": "2007-03-01", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Киця Ярослав Володимирович", "дата народження": "2007-01-03", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Кравчук Юлія Юріївна", "дата народження": "2007-09-24", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Мартинюк Діана Сергіївна", "дата народження": "2007-03-03", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Назарук Діана Володимирівна", "дата народження": "2006-12-05", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Пасічник Софія Назарівна", "дата народження": "2007-06-09", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Пустовіт Анастасія Дмитрівна", "дата народження": "2007-08-20", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Пучкова Валерія Ігорівна", "дата народження": "2007-09-29", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Сичук Ангеліна Олександрівна", "дата народження": "2006-11-15", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Слободянюк Вікторія Вікторівна", "дата народження": "2007-06-08", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Стаськова Валентина Анатоліївна", "дата народження": "2007-02-11", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
    {"ПІП": "Харкевич Руслан Сергійович", "дата народження": "2007-01-07", "адреса": "м. Вінниця", "курс": 1, "група": "1-СОМ"},
    {"ПІП": "Черешня Станіслав Сергійович", "дата народження": "2006-07-03", "адреса": "м. Вінниця", "курс": 1, "група": "1-СОМ"},
    {"ПІП": "Чорна Єлизавета Миколаївна", "дата народження": "2007-09-11", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"}
]

print("Прізвища студентів 1-го курсу:\n" + "\n".join([s["ПІП"].split()[0]
        for s in students
            if s["курс"] == 1]))
# Out:
# Прізвища студентів 1-го курсу:
# Адамлюк
# Бичко
# Бугрова
# Бурейко
# Гончарук
# Гріщенко
# Гунько
# Дорош
# Журавель
# Зінченко
# Калінін
# Кисіль
# Киця
# Кравчук
# Мартинюк
# Назарук
# Пасічник
# Пустовіт
# Пучкова
# Сичук
# Слободянюк
# Стаськова
# Харкевич
# Черешня
# Чорна

# %%
#3 через клас (class)

class Student:
    students = [
        {"ПІП": "Адамлюк Владислав Романович", "дата народження": "2005-06-16", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Бичко Дар'я Юріївна", "дата народження": "2007-06-20", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Бугрова Юлія Вікторівна", "дата народження": "2007-06-15", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Бурейко Володимир Омелянович", "дата народження": "1960-02-04", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Гончарук Ангеліна Сергіївна", "дата народження": "2007-05-18", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Гріщенко Світлана Василівна", "дата народження": "2007-10-12", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Гунько Іван Романович", "дата народження": "2007-12-21", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Дорош Руслан Миколайович", "дата народження": "2007-02-01", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Журавель Альона Олександрівна", "дата народження": "2007-02-08", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Зінченко Максим Олександрович", "дата народження": "2007-06-30", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Калінін Євген Олексійович", "дата народження": "2001-08-21", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Кисіль Яна Юріївна", "дата народження": "2007-03-01", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Киця Ярослав Володимирович", "дата народження": "2007-01-03", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Кравчук Юлія Юріївна", "дата народження": "2007-09-24", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Мартинюк Діана Сергіївна", "дата народження": "2007-03-03", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Назарук Діана Володимирівна", "дата народження": "2006-12-05", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Пасічник Софія Назарівна", "дата народження": "2007-06-09", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Пустовіт Анастасія Дмитрівна", "дата народження": "2007-08-20", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Пучкова Валерія Ігорівна", "дата народження": "2007-09-29", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Сичук Ангеліна Олександрівна", "дата народження": "2006-11-15", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Слободянюк Вікторія Вікторівна", "дата народження": "2007-06-08", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Стаськова Валентина Анатоліївна", "дата народження": "2007-02-11", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"},
        {"ПІП": "Харкевич Руслан Сергійович", "дата народження": "2007-01-07", "адреса": "м. Вінниця", "курс": 1, "група": "1-СОМ"},
        {"ПІП": "Черешня Станіслав Сергійович", "дата народження": "2006-07-03", "адреса": "м. Вінниця", "курс": 1, "група": "1-СОМ"},
        {"ПІП": "Чорна Єлизавета Миколаївна", "дата народження": "2007-09-11", "адреса": "м. Вінниця", "курс": 1, "група": "1-CОМ"}
    ]

print("Прізвища студентів 1-го курсу:\n" + "\n".join([s["ПІП"].split()[0] for s in Student.students if s["курс"] == 1]))
# Out:
# Прізвища студентів 1-го курсу:
# Адамлюк
# Бичко
# Бугрова
# Бурейко
# Гончарук
# Гріщенко
# Гунько
# Дорош
# Журавель
# Зінченко
# Калінін
# Кисіль
# Киця
# Кравчук
# Мартинюк
# Назарук
# Пасічник
# Пустовіт
# Пучкова
# Сичук
# Слободянюк
# Стаськова
# Харкевич
# Черешня
# Чорна

# %% [markdown]
# # **Структура містить поля: марка машин, рік випуску, ціна. Вивести на екран дані про наявність на складі автомашин і отримати інформацію про марки та рік випуску машин, ціна яких менша, ніж 40000 грн**

# %%
#4 через словник (dict)

cars = [
    {"марка": "Toyota Corolla", "рік": 2018, "ціна": 35000},
    {"марка": "BMW X5", "рік": 2020, "ціна": 65000},
    {"марка": "Renault Logan", "рік": 2016, "ціна": 27000},
    {"марка": "Mazda 3", "рік": 2019, "ціна": 39000},
]

print("Наявність на складі:")
for car in cars:
    print(f"Марка: {car['марка']}, Рік: {car['рік']}, Ціна: {car['ціна']} грн")

print("\nМашини з ціною менше 40000 грн:")
for car in cars:
    if car["ціна"] < 40000:
        print(f"{car['марка']} ({car['рік']})")
# Out:
# Наявність на складі:
# Марка: Toyota Corolla, Рік: 2018, Ціна: 35000 грн
# Марка: BMW X5, Рік: 2020, Ціна: 65000 грн
# Марка: Renault Logan, Рік: 2016, Ціна: 27000 грн
# Марка: Mazda 3, Рік: 2019, Ціна: 39000 грн
#
# Машини з ціною менше 40000 грн:
# Toyota Corolla (2018)
# Renault Logan (2016)
# Mazda 3 (2019)

# %%
#4 через клас (class)

class CarStock:
    авто = [
        {"марка": "Toyota Corolla", "рік": 2018, "ціна": 35000},
        {"марка": "BMW X5", "рік": 2020, "ціна": 65000},
        {"марка": "Renault Logan", "рік": 2016, "ціна": 27000},
        {"марка": "Mazda 3", "рік": 2019, "ціна": 39000},
    ]

print("Наявність на складі:")
for car in CarStock.авто:
    print(f"Марка: {car['марка']}, Рік: {car['рік']}, Ціна: {car['ціна']} грн")

print("\nМашини з ціною менше 40000 грн:")
for car in CarStock.авто:
    if car["ціна"] < 40000:
        print(f"{car['марка']} ({car['рік']})")
# Out:
# Наявність на складі:
# Марка: Toyota Corolla, Рік: 2018, Ціна: 35000 грн
# Марка: BMW X5, Рік: 2020, Ціна: 65000 грн
# Марка: Renault Logan, Рік: 2016, Ціна: 27000 грн
# Марка: Mazda 3, Рік: 2019, Ціна: 39000 грн
#
# Машини з ціною менше 40000 грн:
# Toyota Corolla (2018)
# Renault Logan (2016)
# Mazda 3 (2019)
